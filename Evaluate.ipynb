# %%
# if use colab, run this part
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Final_project')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #PIP statements

# %%
# !pip install -r stat453_proj/instruction-tuned-sd/requirements.txt
# !pip install diffusers
# !pip install open_clip_torch transformers
# !pip install torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 32.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 53.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...

# %%
# !pip install datasets
# !pip install openai-clip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for openai-clip: filename=openai_clip-1.0.1-py3-none-any.whl size=1368605 sha256=850d9f9495e5a65d51d5f726ee1544e7dfe3cb139d9a3f306b996555b75118c4
#   Stored in directory: /root/.cache/pip/wheels/08/77/8e/8d2f862df6bf7fb4e2007062d2cbaeae49862ec7b56d041229
# Successfully built openai-clip
# ...

# %% [markdown]
# #Image Captioning

# %%
import open_clip
import torch

model, _, transform = open_clip.create_model_and_transforms(
  model_name="coca_ViT-L-14",
  pretrained="mscoco_finetuned_laion2B-s13B-b90k"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# open_clip_pytorch_model.bin:   0%|          | 0.00/2.55G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-06e567f0f34e> in <cell line: 4>()
#       2 import torch
#       3
# ----> 4 model, _, transform = open_clip.create_model_and_transforms(
#       5   model_name="coca_ViT-L-14",
# ...

# %%
from IPython.display import Image
import os

# %%
a = os.listdir("custom_datasets_2/source")
source_list = []
for name in a:
  if name!= ".DS_Store":
    source_list.append(name)

# %%
from PIL import Image
caption_list = []
for i in range(len(source_list)):
  path = os.path.join("custom_datasets_2","source",source_list[i])
  im = Image.open(path).convert("RGB")
  im = transform(im).unsqueeze(0)

  with torch.no_grad(), torch.cuda.amp.autocast():
    generated = model.generate(im)

  caption = open_clip.decode(generated[0]).split("<end_of_text>")[0].replace("<start_of_text>", "")
  caption_list.append(caption)

# %% [markdown]
# # CLIP Similarity
# - we are calculating the the similarity score between the generated images by our model and the targets.

# %%
import torch
from diffusers import StableDiffusionInstructPix2PixPipeline
from diffusers import StableDiffusionImg2ImgPipeline

device = "cuda" if torch.cuda.is_available() else "cpu"

instruct_pix2pix_pipeline = StableDiffusionInstructPix2PixPipeline.from_pretrained(
    "tianyi0216/model3", torch_dtype=torch.float16
).to(device)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# ...

# %%
instruct_pix2pix_original = StableDiffusionInstructPix2PixPipeline.from_pretrained(
    "timbrooks/instruct-pix2pix", torch_dtype=torch.float16
).to(device)
# Out:
# model_index.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/518 [00:00<?, ?B/s]
# safety_checker/config.json:   0%|          | 0.00/4.91k [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/569 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# ...

# %%
import clip
import torch
from PIL import Image

# Load the CLIP model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# Function to compute CLIP similarity
def compute_clip_similarity(image1, image2):
    image1 = preprocess(image1).unsqueeze(0).to(device)
    image2 = preprocess(image2).unsqueeze(0).to(device)

    with torch.no_grad():
        image_features1 = model.encode_image(image1)
        image_features2 = model.encode_image(image2)

    # Cosine similarity
    similarity = torch.nn.functional.cosine_similarity(image_features1, image_features2)
    return similarity.item()
# Out:
# 100%|███████████████████████████████████████| 338M/338M [00:05<00:00, 69.8MiB/s]

# %%
# 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

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("tianyi0216/MagicBrush_PartOnly", split="train")
dataset.features
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split:   0%|          | 0/280 [00:00<?, ? examples/s]
# {'source_img': Image(mode=None, decode=True, id=None),
#  'source_caption': Value(dtype='string', id=None),
#  'instruction': Value(dtype='string', id=None),
#  'target_img': Image(mode=None, decode=True, id=None),
#  'target_caption': Value(dtype='string', id=None)}

# %%
from datasets import load_dataset

dataset_cyclegan = load_dataset("tianyi0216/cyclegan_test_ds", split="train")
dataset_cyclegan.features
# Out:
# ...
# Generating train split:   0%|          | 0/280 [00:00<?, ? examples/s]
# {'source_img': Image(mode=None, decode=True, id=None),
#  'source_caption': Value(dtype='string', id=None),
#  'instruction': Value(dtype='string', id=None),
#  'target_img': Image(mode=None, decode=True, id=None),
#  'target_caption': Value(dtype='string', id=None)}

# %%
with open("output/similarity_ours.txt", "w") as f:
  f.write("")
with open("output/finished_indices.txt", "w") as f:
  f.write("")

# %%
# new similarity
indices_list = [i for i in range(25)] + [i for i in range(70, 95)] + [i for i in range(140, 165)] + [i for i in range(210, 235)]

for idx in indices_list:
    target_img = dataset_cyclegan[idx]["target_img"]
    instruction = dataset[idx]["instruction"]
    #generate_img = edit_image(source_img,instruction)
    generate_img = Image.open(f"output/output{idx}.png")
    #source_caption = dataset[idx]["source_caption"]
    #target_caption = dataset[idx]["target_caption"]
    # target_img = dataset[idx]["target_img"]
    score_1 = compute_clip_similarity(target_img, generate_img)
    score = score_1
    with open("output/similarity_ours.txt", "a") as f:
        f.write(f"{score}\n")

# %%
with open("output2/similarity_original.txt", "w") as f:
  f.write("")

# %%
for idx in indices_list:
    target_img = dataset_cyclegan[idx]["target_img"]
    instruction = dataset[idx]["instruction"]
    #generate_img = edit_image(source_img,instruction)
    generate_img = Image.open(f"output2/original{idx}.png")
    #source_caption = dataset[idx]["source_caption"]
    #target_caption = dataset[idx]["target_caption"]
    # target_img = dataset[idx]["target_img"]
    score_1 = compute_clip_similarity(target_img, generate_img)
    score = score_1
    with open("output2/similarity_original.txt", "a") as f:
        f.write(f"{score}\n")

# %%
with open("output3/similarity_ours.txt", "w") as f:
  f.write("")
with open("output3/finished_indices.txt", "w") as f:
  f.write("")

# %%
# total_simiarity_ours = 0.0
similarity_ours = []
num_images = 0
indices_list = [i for i in range(25)] + [i for i in range(70, 95)] + [i for i in range(140, 165)] + [i for i in range(210, 235)]

for idx in indices_list:
  index_visited = None
  with open("output3/finished_indices.txt", "r") as f:
    for line in f:
      if line.strip() == str(idx):
        index_visited = True
        break
  if index_visited:
    continue
  source_img = dataset[idx]["source_img"]
  st_prompt = dataset[idx]["instruction"]
  result = instruct_pix2pix_pipeline(st_prompt, image=source_img, num_inference_steps=200, image_guidance_scale=1.1).images[0]
  #total_simiarity_ours += compute_clip_similarity(result, dataset[idx]["target_img"])
  # save image
  result.save("output3/output" + str(idx) + ".png")
  with open("output3/finished_indices.txt", "a") as f:
    f.write(str(idx) + "\n")
  score = compute_clip_similarity(result, dataset_cyclegan[idx]["target_img"])
  similarity_ours.append(score)
  with open("output3/similarity_ours.txt", "a") as f:
    f.write(str(score) + "\n")
# Out:
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
with open("output/similarity_cycle_gan.txt", "w") as f:
  f.write("")

# %%
# total_simiarity_ours = 0.0
similarity_stylegan = []
num_images = 0
indices_list = [i for i in range(25)] + [i for i in range(70, 95)] + [i for i in range(140, 165)] + [i for i in range(210, 235)]

for idx in indices_list:
  #result = instruct_pix2pix_pipeline(st_prompt, image=source_img, num_inference_steps=200, image_guidance_scale=1.1).images[0]
  result = dataset[idx]["target_img"]
  result_2 = dataset_cyclegan[idx]["target_img"]
  #total_simiarity_ours += compute_clip_similarity(result, dataset[idx]["target_img"])
  # save image
  #result.save("output/output" + str(idx) + ".png")
  #with open("output/finished_indices.txt", "a") as f:
  #  f.write(str(idx) + "\n")
  similarity = compute_clip_similarity(result_2, result)
  similarity_stylegan.append(similarity)
  with open("output/similarity_cycle_gan.txt", "a") as f:
    f.write(str(similarity) + "\n")

# %%
with open("output2/similarity_ours_2.txt", "w") as f:
  f.write("")
with open("output2/finished_indices_2.txt", "w") as f:
  f.write("")
with open("output2/similarity_original.txt", "w") as f:
  f.write("")

# %%
# total_simiarity_ours = 0.0
similarity_ours_2 = []
num_images = 0
indices_list = [i for i in range(25)] + [i for i in range(70, 95)] + [i for i in range(140, 165)] + [i for i in range(210, 235)]

for idx in indices_list:
  index_visited = None
  with open("output2/finished_indices_2.txt", "r") as f:
    for line in f:
      if line.strip() == str(idx):
        index_visited = True
        break
  if index_visited:
    continue
  source_img = dataset[idx]["source_img"]
  st_prompt = dataset[idx]["instruction"]
  #result = instruct_pix2pix_pipeline(st_prompt, image=source_img, num_inference_steps=200, image_guidance_scale=1.5, guidance_scale = 7.5).images[0]
  #total_simiarity_ours += compute_clip_similarity(result, dataset[idx]["target_img"])
  # save image
  #result.save("output2/output" + str(idx) + ".png")
  #with open("output2/finished_indices_2.txt", "a") as f:
  #  f.write(str(idx) + "\n")
  #similarity = compute_clip_similarity(result, dataset[idx]["target_img"])
  #similarity_ours_2.append(similarity)
  #with open("output2/similarity_ours_2.txt", "a") as f:
  #  f.write(str(similarity) + "\n")
  result_original = instruct_pix2pix_original(st_prompt, image=source_img, num_inference_steps=200, image_guidance_scale=1.5, guidance_scale = 7.5).images[0]
  result_original.save("output2/original" + str(idx) + ".png")
  similarity_original = compute_clip_similarity(result_original, dataset[idx]["target_img"])
  with open("output2/similarity_original.txt", "a") as f:
    f.write(str(similarity_original) + "\n")
# Out:
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %% [markdown]
# # Clip directional similarity

# %%
import torch
from transformers import (
    CLIPTokenizer,
    CLIPTextModelWithProjection,
    CLIPVisionModelWithProjection,
    CLIPImageProcessor,
)

device = "cuda" if torch.cuda.is_available() else "cpu"
clip_id = "openai/clip-vit-large-patch14"
tokenizer = CLIPTokenizer.from_pretrained(clip_id)
text_encoder = CLIPTextModelWithProjection.from_pretrained(clip_id).to(device)
image_processor = CLIPImageProcessor.from_pretrained(clip_id)
image_encoder = CLIPVisionModelWithProjection.from_pretrained(clip_id).to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.52k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]

# %%
import torch.nn as nn
import torch.nn.functional as F
import numpy as np


class DirectionalSimilarity(nn.Module):
    def __init__(self, tokenizer, text_encoder, image_processor, image_encoder):
        super().__init__()
        self.tokenizer = tokenizer
        self.text_encoder = text_encoder
        self.image_processor = image_processor
        self.image_encoder = image_encoder

    def preprocess_image(self, image):
        image = self.image_processor(image, return_tensors="pt")["pixel_values"]
        return {"pixel_values": image.to(device)}

    def tokenize_text(self, text):
        inputs = self.tokenizer(
            text,
            max_length=self.tokenizer.model_max_length,
            padding="max_length",
            truncation=True,
            return_tensors="pt",
        )
        return {"input_ids": inputs.input_ids.to(device)}

    def encode_image(self, image):
        preprocessed_image = self.preprocess_image(image)
        image_features = self.image_encoder(**preprocessed_image).image_embeds
        image_features = image_features / image_features.norm(dim=1, keepdim=True)
        return image_features

    def encode_text(self, text):
        tokenized_text = self.tokenize_text(text)
        text_features = self.text_encoder(**tokenized_text).text_embeds
        text_features = text_features / text_features.norm(dim=1, keepdim=True)
        return text_features

    def compute_directional_similarity(self, img_feat_one, img_feat_two, text_feat_one, text_feat_two):
        sim_direction = F.cosine_similarity(img_feat_two - img_feat_one, text_feat_two - text_feat_one)
        return sim_direction

    def forward(self, image_one, image_two, caption_one, caption_two):
        img_feat_one = self.encode_image(image_one)
        img_feat_two = self.encode_image(image_two)
        text_feat_one = self.encode_text(caption_one)
        text_feat_two = self.encode_text(caption_two)
        directional_similarity = self.compute_directional_similarity(
            img_feat_one, img_feat_two, text_feat_one, text_feat_two
        )
        return directional_similarity

# %%
# generated image by our model

def edit_image(input_image, instruction):
    image = instruct_pix2pix_pipeline(
        instruction,
        image=input_image,
        num_inference_steps=200,
        image_guidance_scale=1.1,
        output_type="np",
    ).images[0]
    return image

# %%
with open("output/directional_similarity_model1.txt", "w") as f:
  f.write("")

# %%
from PIL import Image
import gc

indices_list = [i for i in range(25)] + [i for i in range(70, 95)] + [i for i in range(140, 165)] + [i for i in range(210, 235)]

# %%
direcitonal_similarity = DirectionalSimilarity(tokenizer, text_encoder, image_processor, image_encoder)
score_list = []

for idx in indices_list:
    source_img = dataset[idx]["source_img"]
    source_img_array = np.array(source_img)
    instruction = dataset[idx]["instruction"]
    #generate_img = edit_image(source_img,instruction)
    generate_img = Image.open(f"output/output{idx}.png")
    source_caption = dataset[idx]["source_caption"]
    target_caption = dataset[idx]["target_caption"]
    # target_img = dataset[idx]["target_img"]
    score_1 = direcitonal_similarity(source_img_array,generate_img,source_caption,target_caption)
    score = float(score_1.detach().cpu())
    with open("output/directional_similarity_model1.txt", "a") as f:
        f.write(f"{score}\n")
    #score_list.append(score)
    gc.collect()

# %%
with open("output2/directional_similarity_ip2p.txt", "w") as f:
  f.write("")

# %%
for idx in indices_list:
    source_img = dataset[idx]["source_img"]
    source_img_array = np.array(source_img)
    instruction = dataset[idx]["instruction"]
    #generate_img = edit_image(source_img,instruction)
    generate_img = Image.open(f"output2/original{idx}.png")
    source_caption = dataset[idx]["source_caption"]
    target_caption = dataset[idx]["target_caption"]
    # target_img = dataset[idx]["target_img"]
    score_1 = direcitonal_similarity(source_img_array,generate_img,source_caption,target_caption)
    score = float(score_1.detach().cpu())
    with open("output2/directional_similarity_ip2p.txt", "a") as f:
        f.write(f"{score}\n")
    #score_list.append(score)
    gc.collect()

# %%
with open("output3/directional_similarity_model3.txt", "w") as f:
  f.write("")

# %%
direcitonal_similarity = DirectionalSimilarity(tokenizer, text_encoder, image_processor, image_encoder)
score_list = []

for idx in indices_list:
    source_img = dataset[idx]["source_img"]
    source_img_array = np.array(source_img)
    instruction = dataset[idx]["instruction"]
    #generate_img = edit_image(source_img,instruction)
    generate_img = Image.open(f"output3/output{idx}.png")
    source_caption = dataset[idx]["source_caption"]
    target_caption = dataset[idx]["target_caption"]
    # target_img = dataset[idx]["target_img"]
    score_1 = direcitonal_similarity(source_img_array,generate_img,source_caption,target_caption)
    score = float(score_1.detach().cpu())
    with open("output3/directional_similarity_model3.txt", "a") as f:
        f.write(f"{score}\n")
    #score_list.append(score)
    gc.collect()

# %% [markdown]
# ## KID (Kernel Inceptional Distance)

# %%
# !pip install torchmetrics
# !pip install torch-fidelity
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 14.7 MB/s eta 0:00:00
# ...

# %%
import torch
from torchmetrics.image.kid import KernelInceptionDistance
from torchvision.transforms import functional as F


def preprocess_image(image):
    image = torch.tensor(image).unsqueeze(0)
    image = image.permute(0, 3, 1, 2) / 255.0
    return F.center_crop(image, (256, 256))

# %%
from PIL import Image
import os
import numpy as np

dataset_path = "artwork"
image_paths = sorted([os.path.join(dataset_path, x) for x in os.listdir(dataset_path)])

real_images = [np.array(Image.open(path).convert("RGB")) for path in image_paths]

# %%
image_paths
# Out:
# ['artwork/00002.jpg',
#  'artwork/00005.jpg',
#  'artwork/00007.jpg',
#  'artwork/00010.jpg',
#  'artwork/00011.jpg',
#  'artwork/00012.jpg',
#  'artwork/00014.jpg',
#  'artwork/00015.jpg',
#  'artwork/00016.jpg',
#  'artwork/00034.jpg',
#  'artwork/Claude_Monet_1.jpg',
#  'artwork/Claude_Monet_10.jpg',
#  'artwork/Claude_Monet_2.jpg',
#  'artwork/Claude_Monet_3.jpg',
#  'artwork/Claude_Monet_4.jpg',
#  'artwork/Claude_Monet_5.jpg',
#  'artwork/Claude_Monet_6.jpg',
#  'artwork/Claude_Monet_7.jpg',
#  'artwork/Claude_Monet_8.jpg',
#  'artwork/Claude_Monet_9.jpg',
#  'artwork/Paul_Cezanne_1.jpg',
#  'artwork/Paul_Cezanne_10.jpg',
#  'artwork/Paul_Cezanne_2.jpg',
#  'artwork/Paul_Cezanne_3.jpg',
#  'artwork/Paul_Cezanne_4.jpg',
#  'artwork/Paul_Cezanne_5.jpg',
#  'artwork/Paul_Cezanne_6.jpg',
#  'artwork/Paul_Cezanne_7.jpg',
#  'artwork/Paul_Cezanne_8.jpg',
#  'artwork/Paul_Cezanne_9.jpg',
#  'artwork/Vincent_van_Gogh_1.jpg',
#  'artwork/Vincent_van_Gogh_10.jpg',
# ...

# %%
real_images = torch.cat([preprocess_image(image) for image in real_images])
print(real_images.shape)
# Out:
# torch.Size([40, 3, 256, 256])

# %%
import random
#indices_list = [i for i in range(25)] + [i for i in range(70, 95)] + [i for i in range(140, 165)] + [i for i in range(210, 235)]

fake_images = []

for idx in range(40):
    rand_idx = None
    if 0 <= idx < 10:
        st_prompt = "change to monet style"
        rand_idx = idx
        #source_img = dataset[rand_idx]["source_img"]
    elif 10 <= idx < 20:
        st_prompt = "change to van gogh style"
        rand_idx = idx + 61
        #source_img = dataset[rand_idx]["source_img"]
    elif 20 <= idx < 30:
        st_prompt = "change to cezanne style"
        rand_idx = idx + 121
        #source_img = dataset[rand_idx]["source_img"]
    elif 30 <= idx < 40:
        st_prompt = "change to ukiyoe style"
        rand_idx = idx + 181
        #source_img = dataset[rand_idx]["source_img"]

    #source_img = dataset[idx]["source_img"]
    img = np.array(Image.open(f'output/output{rand_idx}.png').convert("RGB"))
    fake_images.append(img)


    #result = instruct_pix2pix_pipeline(st_prompt, image=source_img, num_inference_steps=200, image_guidance_scale=1.1).images[0]
    #fake_images.append(np.array(result))

# %%
fake_images = torch.cat([preprocess_image(image) for image in fake_images])
print(fake_images.shape)
# Out:
# torch.Size([40, 3, 256, 256])

# %%
# !pip install torchmetrics[image]

# %%
kid = KernelInceptionDistance(normalize=True, subset_size = 40)
kid.update(real_images, real=True)
kid.update(fake_images, real=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)  # noqa: B028

# %%
kid.compute()
# Out:
# (tensor(0.0300), tensor(2.9068e-07))

# %%
fake_images = []

for idx in range(40):
    rand_idx = None
    if 0 <= idx < 10:
        st_prompt = "change to monet style"
        rand_idx = idx
        #source_img = dataset[rand_idx]["source_img"]
    elif 10 <= idx < 20:
        st_prompt = "change to van gogh style"
        rand_idx = idx + 61
        #source_img = dataset[rand_idx]["source_img"]
    elif 20 <= idx < 30:
        st_prompt = "change to cezanne style"
        rand_idx = idx + 121
        #source_img = dataset[rand_idx]["source_img"]
    elif 30 <= idx < 40:
        st_prompt = "change to ukiyoe style"
        rand_idx = idx + 181
        #source_img = dataset[rand_idx]["source_img"]

    #source_img = dataset[idx]["source_img"]
    img = np.array(Image.open(f'output2/original{rand_idx}.png').convert("RGB"))
    fake_images.append(img)

# %%
fake_images = torch.cat([preprocess_image(image) for image in fake_images])
print(fake_images.shape)
# Out:
# torch.Size([40, 3, 256, 256])

# %%
kid = KernelInceptionDistance(normalize=True, subset_size = 40)
kid.update(real_images, real=True)
kid.update(fake_images, real=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)  # noqa: B028

# %%
kid.compute()
# Out:
# (tensor(0.0421), tensor(1.9187e-07))

# %%
import random
#indices_list = [i for i in range(25)] + [i for i in range(70, 95)] + [i for i in range(140, 165)] + [i for i in range(210, 235)]

fake_images = []

for idx in range(40):
    rand_idx = None
    if 0 <= idx < 10:
        st_prompt = "change to monet style"
        rand_idx = idx
        #source_img = dataset[rand_idx]["source_img"]
    elif 10 <= idx < 20:
        st_prompt = "change to van gogh style"
        rand_idx = idx + 61
        #source_img = dataset[rand_idx]["source_img"]
    elif 20 <= idx < 30:
        st_prompt = "change to cezanne style"
        rand_idx = idx + 121
        #source_img = dataset[rand_idx]["source_img"]
    elif 30 <= idx < 40:
        st_prompt = "change to ukiyoe style"
        rand_idx = idx + 181
        #source_img = dataset[rand_idx]["source_img"]

    #source_img = dataset[idx]["source_img"]
    img = np.array(Image.open(f'output3/output{rand_idx}.png').convert("RGB"))
    fake_images.append(img)


    #result = instruct_pix2pix_pipeline(st_prompt, image=source_img, num_inference_steps=200, image_guidance_scale=1.1).images[0]
    #fake_images.append(np.array(result))

# %%
fake_images = torch.cat([preprocess_image(image) for image in fake_images])
print(fake_images.shape)
# Out:
# torch.Size([40, 3, 256, 256])

# %%
kid = KernelInceptionDistance(normalize=True, subset_size = 40)
kid.update(real_images, real=True)
kid.update(fake_images, real=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100%|██████████| 91.2M/91.2M [00:01<00:00, 58.1MB/s]

# %%
kid.compute()
# Out:
# (tensor(0.0335), tensor(1.8049e-07))
